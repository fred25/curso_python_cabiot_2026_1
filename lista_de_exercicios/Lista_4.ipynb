# %% [markdown]
# # Lista de exercícios 4
#
# Exercícios relativos ao conteúdo da aula 4.
#
# Você deve substituir as `...` nos blocos de código com a sua resposta para o problema proposto.
#
# ---
#
# > Links interessantes:
#
# >   Galeria de gráficos do `seaborn`: https://seaborn.pydata.org/examples/index.html
#
# >   Documentação da função `load_dataset`, caso queiram explorar outros conjuntos de dados: https://seaborn.pydata.org/generated/seaborn.load_dataset.html
#
# >   Documentação do `pandas`: https://pandas.pydata.org/docs/
#
# > Documentação do `scipy.stats`: https://docs.scipy.org/doc/scipy/reference/stats.html

# %%
# importando as bibliotecas pra vocês
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## Desafio 1:
#
# Abra o conjunto de dados `dados_turma.csv` e calcule as seguinte métricas:
#
# - Média global de notas do colégio
# - Desvio padrão de notas do colégio
# - Médias e desvio de notas de cada turma
# - Médias e desvio de altura dos meninos e meninas
#
# Por fim, crie gráficos de distribuição, um para a altura e um para as notas.

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# # Desafio 2:
#
# Abra do dataset `attention` disponível na biblioteca `seaborn`. Ele contém dados de indivíduos que fizeram a mesma prova, porém alguns estavam 100% focados e outros tinham distratores. Faça um gráfico de barras comparando as pontuações dos dois grupos.
#
# > Dica utilize `sns.barplot()`
#
# Depois disso faça um teste estatístico e re-gere o gráfico com os asteriscos demonstrando se houve ou não diferença estatística.

# %%
# carregando os dados
dados_attention = sns.load_dataset("attention")
...

# %% [markdown]
# ## Desafio 3:
#
# Abra o dataset `iris` da biblioteca `seaborn` (o mesmo utilizado na ultima aula) e trace duas regressões lineares uma entre as medidas das sépalas e outra entre a medida das pétalas e responta, qual delas é mais correlacionada?

# %%
# carregando os dados
dados_iris = sns.load_dataset("iris")
...
