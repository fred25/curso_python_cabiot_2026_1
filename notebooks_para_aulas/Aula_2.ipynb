# %% [markdown]
# # Aula 2 - Programação Básica
#
# **Conteúdos:**
# - Controle de fluxo
#     - If-else
#     - Loops
# - Estruturas de dados
#     - list
#     - tuple
#     - dict
#     - set
# - Introdução a bibliotecas
# - Modularização do programa

# %% [markdown]
# ## Fluxo não linear: Condições
#
# Podemos fazer escolhas no código e para isso faremos a seguinte estrutura:
# ```python
# if condição:
#     bloco caso condição seja verdadeira
# elif outra condição
#     bloco caso outra condição seja verdadeira
# else
#     bloco caso tudo seja falso
# ```
# ---
# Vamos implementar a arvore de decisão do slide:

# %%
# Vamos definir as características da festa
festa_boa = False
comida_gratis = True

# implemente aqui a arvore de decisão
...

# %% [markdown]
# As condições também funcionam com operações lógicas:

# %%
# Verifique se as idades são iguais
minha_idade = 20
tua_idade = 25

# Implemente aqui a verificação se temos idades iguais
...

# %% [markdown]
# ## Operadores lógicos
#
# Para valores lógicos temos novos operadores:

# %% [markdown]
# <div style="display: flex; gap: 20px;">
#
# <div>
#
# `and`:
#
# | A | B | A `and` B |
# |---|---|-----------|
# | 0 | 0 | 0 |
# | 1 | 0 | 0 |
# | 0 | 1 | 0 |
# | 1 | 1 | 1 |
#
# </div>
#
# <div>
#
# `or`:
#
# | A | B | A `or` B |
# |---|---|-----------|
# | 0 | 0 | 0 |
# | 1 | 0 | 1 |
# | 0 | 1 | 1 |
# | 1 | 1 | 1 |
#
# </div>
#
# <div>
#
# `not`:
#
# | A | `not` A |
# |---|---------|
# | 0 | 1 |
# | 1 | 0 |
#
# </div>
#
# </div>

# %% [markdown]
# Também temos o operador `in` que verifica se está dentro de algo:
# ```python
# "a" in "amor" -> True
# ```

# %%
# vamos programar o exemplo do cinema
# < 18 pagam meia
# > 60 pagam inteira
# não formados pagam meia
idade = 21
formado = False

# faça as verificações para a entrada no cinema

# %% [markdown]
# ## Estruturas de dados
#
# Como podemos armazenas dados múltiplos?
#
# ---
# - `list` -> `[1, "hey", 3]`:
#     - São mutáveis
#     - Dados heterogêneos
#     - Ordenadas

# %%
# Crie uma lista
lista = ...
print(lista)

# %%
# mostre o segundo elemento dessa lista
print(...)

# %%
# mostre do 3 até o 5 elemento da lista
print(...)

# %%
# troque o ultimo elemento da lista por 5
...
# adicione um elemento "palavra" no final da lista
...

# mostre a lista
print(lista)

# %% [markdown]
# - `tuple` -> `(1, 2, 3)`
#     - Iguais as listas, mas imutáveis
#
# - `dict` -> `{"chave" : "valor", "outra" : 20}`
#     - Pares de chave e valor

# %%
# crie um dicionário
dicionario = ...
print(dicionario)

# %%
# Mostre um elemento de seu dicionário
print(...)

# %%
# Modifique um dos itens do dicionario
...
# Adicione uma nova chave ao dicionario
...

# Mostre o dicionário
print(dicionario)

# %% [markdown]
# - `set` -> `{1, 2, "A"}`
#     - não ordenado
#     - mutável
#     - não permite repetições

# %%
# crie dois conjuntos (set)
conjunto1 = ...
conjunto2 = ...


print(conjunto1, conjunto2)

# %%
# mostre a união e a intersecção desses conjuntos
print(...)

# %% [markdown]
# ## Controle de fluxo - loops
#
# Como podemos fazer coisas repetidas vezes?
#
# Utilizando loops, as suas principais estruturas são:
# - `while`
# - `for`
#
# ---
#
# Exemplo de estrutura `while`:
# ```python
# while condição:
#     bloco de código
# ```
# Executa o bloco de código enquanto a condição for verdadeira

# %%
# Crie um pequeno contador com while:
...

# %% [markdown]
# Exemplo de estrutura `for`:
# ```python
# for valor in estrutura:
#     bloco de código
# ```
# Executa o bloco de código uma vez para cada componente em uma estrutura de dados.

# %%
# Com for eleve ao quadrado todos os itens de uma lista e coloque numa lista nova
lista = [0, 1, 2, 3, 4]
lista_nova = []
...

# %% [markdown]
# ## Desafio 1
# Vocês devem criar uma função que receba uma sequência de RNA, considere que ela começa com AUG
# Ela deve mostrar o resultado da proteína codificada por esse RNA.
#
# Considere que a tabela dos códons está organizada no dicionario `tabela_codons`

# %%
tabela_codons = {'UUU': 'F', 'CUU': 'L', 'AUU': 'I', 'GUU': 'V',
                 'UUC': 'F', 'CUC': 'L', 'AUC': 'I', 'GUC': 'V',
                 'UUA': 'L', 'CUA': 'L', 'AUA': 'I', 'GUA': 'V',
                 'UUG': 'L', 'CUG': 'L', 'AUG': 'M', 'GUG': 'V',
                 'UCU': 'S', 'CCU': 'P', 'ACU': 'T', 'GCU': 'A',
                 'UCC': 'S', 'CCC': 'P', 'ACC': 'T', 'GCC': 'A',
                 'UCA': 'S', 'CCA': 'P', 'ACA': 'T', 'GCA': 'A',
                 'UCG': 'S', 'CCG': 'P', 'ACG': 'T', 'GCG': 'A',
                 'UAU': 'Y', 'CAU': 'H', 'AAU': 'N', 'GAU': 'D',
                 'UAC': 'Y', 'CAC': 'H', 'AAC': 'N', 'GAC': 'D',
                 'UAA': 'Stop', 'CAA': 'Q', 'AAA': 'K', 'GAA': 'E',
                 'UAG': 'Stop', 'CAG': 'Q', 'AAG': 'K', 'GAG': 'E',
                 'UGU': 'C', 'CGU': 'R', 'AGU': 'S', 'GGU': 'G',
                 'UGC': 'C', 'CGC': 'R', 'AGC': 'S', 'GGC': 'G', 
                 'UGA': 'Stop', 'CGA': 'R', 'AGA': 'R', 'GGA': 'G',
                 'UGG': 'W', 'CGG': 'R', 'AGG': 'R', 'GGG': 'G'}

sequencia = "AUGGAAUCUACUCGUGAAUAA"

# %% [markdown]
# ## Bibliotecas
#
# Não precisamos reinventar a roda toda vez!
#
# Podemos utilizar códigos de outras pessoas da seguinte maneira
#
# ```python
# import nome_do_codigo
# import nome_do_codigo.parte_do_codigo
# import nome_do_codigo as cod
# from nome_do_codigo import funcionalidade
# ```
#
# Porém, para isso precisamos instalar os códigos primeiro, para isso utilizamos o pip
# ```bash
# pip install nome_do_codigo
# ```
#
# Vamos usar o `biopython`!
#
# https://biopython.org/

# %%
# Instale o biopython
...

# %%
# Importe a funcionalidade Seq modulo Seq do biopython
...

# %% [markdown]
# Com o biopython, podemos criar objetos de um novo tipo chamado Seq da seguinte maneira
# ```python
# sequencia_texto = "ATCG"
#
# sequencia = Seq(sequencia_texto)
# ```

# %%
# Crie o objeto Seq da sequência abaixo
sequencia = "AUGGAAUCUACUCGUGAAUAA"
...

# %%
# Mostre o complemento da sequência
...

# %% [markdown]
# ## Desafio!
#
# Encontre na documentação do `biopython` a função que traduz RNA em proteína

# %%
# Mostre a proteína da sequência
...
